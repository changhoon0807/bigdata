# %% [markdown]
# # Pandas
#
# ## 1차원 Series, 2차원 dataframe

# %%
import numpy as np
np.array([[1, 2], [3, 4]])
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
import pandas as pd

# %%
df = pd.DataFrame([[1, 2], [3, 4]])

# %%
df
# Out:
#    0  1
# 0  1  2
# 1  3  4

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df)==pd.DataFrame
# Out:
# True

# %%
df.set_index(0)
# Out:
#    1
# 0
# 1  2
# 3  4

# %%
df = pd.DataFrame([[1, 2], [3, 4], [5, 6]])

# %%
df
# Out:
#    0  1
# 0  1  2
# 1  3  4
# 2  5  6

# %%
df.columns = ['KOR', 'USA']

# %%
df.index = [17, 18, 19]

# %%
df
# Out:
#     KOR  USA
# 17    1    2
# 18    3    4
# 19    5    6

# %%
df = pd.DataFrame({'a':[1, 2], 'b':[3, 4]}) # 딕셔너리

# %%
df
# Out:
#    a  b
# 0  1  3
# 1  2  4

# %% [markdown]
# - 데이터프레임 통계량

# %%
type(df.mean()) # 열 기준으로 평균 구하기
# Out:
# pandas.core.series.Series

# %%
df.mean().to_frame('mean')
# Out:
#    mean
# a   1.5
# b   3.5

# %%
df = pd.DataFrame([[1, 2], [3, 4], [5, 6]])
df.columns = ['KOR', 'USA']
df.index = [17, 18, 19]
df
# Out:
#     KOR  USA
# 17    1    2
# 18    3    4
# 19    5    6

# %%
df.apply(['mean', 'median', 'sum', 'std'])
# Out:
#         KOR   USA
# mean    3.0   4.0
# median  3.0   4.0
# sum     9.0  12.0
# std     2.0   2.0

# %% [markdown]
# ## 슬라이스

# %%
df
# Out:
#     KOR  USA
# 17    1    2
# 18    3    4
# 19    5    6

# %%
df.loc[18:, :]
# Out:
#     KOR  USA
# 18    3    4
# 19    5    6

# %%
df.loc[17, :]
# Out:
# KOR    1
# USA    2
# Name: 17, dtype: int64

# %%
df.loc[17]
# Out:
# KOR    1
# USA    2
# Name: 17, dtype: int64

# %% [markdown]
# - 값 지정

# %%
df
# Out:
#     KOR  USA
# 17    1    2
# 18    3    4
# 19    5    6

# %%
df.loc[18, 'KOR'] = 0

# %%
df
# Out:
#     KOR  USA
# 17    1    2
# 18    0    4
# 19    5    6

# %%
df.loc[:, 'USA'] = 1

# %%
df
# Out:
#     KOR  USA
# 17    1    1
# 18    0    1
# 19    5    1

# %%
df1 = df.loc[18:,:].copy()

# %%
df1.loc[:, :] = [[1, 2], [3, 4]]
df1
# Out:
#     KOR  USA
# 18    1    2
# 19    3    4

# %%
# Out:
#     KOR  USA
# 17    1    2
# 18    3    4
# 19    5    6

# %% [markdown]
# ## 멀티인덱스

# %%
df = pd.DataFrame({'country':['USA', 'KOR', 'USA', 'KOR'], 'pop':[1, 2, 3, 4], 'gdp':[3, 4, 5, 6]}, index = [16, 16, 17, 17])

# %%
df
# Out:
#    country  pop  gdp
# 16     USA    1    3
# 16     KOR    2    4
# 17     USA    3    5
# 17     KOR    4    6

# %%
df = df.set_index('country', append=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7644\168031838.py in ?()
# ----> 1 df = df.set_index('country', append=True)
#
# c:\Users\bok\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    6118                     if not found:
#    6119                         missing.append(col)
#    6120
#    6121         if missing:
# -> 6122             raise KeyError(f"None of {missing} are in the columns")
#    6123
#    6124         if inplace:
#    6125             frame = self
#
# KeyError: "None of ['country'] are in the columns"

# %%
df
# Out:
#             pop  gdp
#    country
# 16 USA        1    3
#    KOR        2    4
# 17 USA        3    5
#    KOR        4    6

# %%
from pandas import MultiIndex as MI

# %%
df.index = MI.from_product([['16', '17'], ['미국', '한국']])

# %%
df
# Out:
#        pop  gdp
# 16 미국    1    3
#    한국    2    4
# 17 미국    3    5
#    한국    4    6

# %%
df.index = pd.MultiIndex.from_product([['16', '17'], ['미국', '한국']])

# %%
df
# Out:
#        pop  gdp
# 16 미국    1    3
#    한국    2    4
# 17 미국    3    5
#    한국    4    6

# %%
df.index = [':'.join(c).strip() for c in df.index.values]

# %%
df.index
# Out:
# Index(['16:미국', '16:한국', '17:미국', '17:한국'], dtype='object')

# %%
df.index.str.split(':').tolist() # str: 인덱스를 문자열로 간주하게 해서 문자열 메서드 사용 가능
# Out:
# [['16', '미국'], ['16', '한국'], ['17', '미국'], ['17', '한국']]

# %% [markdown]
# 라벨이 주어진 형태에 따라 멀티인덱스 생성 함수를 선택
#
#
# ```
# - from_tuples() : [['16', '미국'], ['16', '한국'], ['17', '미국'], ['17', '한국']]
# - from_product() : [['16', '17'], ['미국', '한국']]
# - from_arrays() : [['16', '16', '17', '17'], ['미국', '미국', '한국', '한국']]
# ```

# %%
df.index = MI.from_tuples(df.index.str.split(':').tolist())

# %%
df
# Out:
#        pop  gdp
# 16 미국    1    3
#    한국    2    4
# 17 미국    3    5
#    한국    4    6

# %% [markdown]
# IndexSlice: 다양한 층위에서 데이터 선택

# %%
df = pd.DataFrame({'country':['USA', 'KOR', 'USA', 'KOR'],
                   'pop':[1, 2, 3, 4],
                   'gdp':[3, 4, 5, 6]},
                  index = [16, 16, 17, 17])

# %%
df = df.set_index('country', append=True)

# %%
df
# Out:
#             pop  gdp
#    country
# 16 USA        1    3
#    KOR        2    4
# 17 USA        3    5
#    KOR        4    6

# %%
idx = pd.IndexSlice

# %%
df.loc[idx[:, 'USA'], :]
# Out:
#             pop  gdp
#    country
# 16 USA        1    3
# 17 USA        3    5

# %%
df.loc[idx[16, 'USA'], :]
# Out:
# pop    1
# gdp    3
# Name: (16, USA), dtype: int64

# %%
df = pd.DataFrame({'country':['USA', 'KOR', 'USA', 'KOR'],
                   'pop':[1, 2, 3, 4],
                   'gdp':[3, 4, 5, 6]},
                  index = [16, 16, 17, 17])

# %%
df
# Out:
#    country  pop  gdp
# 16     USA    1    3
# 16     KOR    2    4
# 17     USA    3    5
# 17     KOR    4    6

# %%
df.loc[df['pop'].ge(3)] # ge: >=
# Out:
#    country  pop  gdp
# 17     USA    3    5
# 17     KOR    4    6

# %%
df
# Out:
#    country  pop  gdp
# 16     USA    1    3
# 16     KOR    2    4
# 17     USA    3    5
# 17     KOR    4    6

# %%
df.loc[df.country.isin(['USA', 'JPN'])]
# Out:
#    country  pop  gdp
# 16     USA    1    3
# 17     USA    3    5

# %% [markdown]
# - droplevels
# - get_level_values
# - reorder_levels

# %%
df
# Out:
#    country  pop  gdp
# 16     USA    1    3
# 16     KOR    2    4
# 17     USA    3    5
# 17     KOR    4    6

# %%
df = df.set_index('country', append=True)

# %%
df
# Out:
#             pop  gdp
#    country
# 16 USA        1    3
#    KOR        2    4
# 17 USA        3    5
#    KOR        4    6

# %%
df.index.names = ['yr', 'country']

# %%
df
# Out:
#             pop  gdp
# yr country
# 16 USA        1    3
#    KOR        2    4
# 17 USA        3    5
#    KOR        4    6

# %%
df.index.get_level_values(0).unique()
# Out:
# Index([16, 17], dtype='int64', name='yr')

# %%
df.index.get_level_values(1).unique()
# Out:
# Index(['USA', 'KOR'], dtype='object', name='country')

# %%
df = df.loc[idx[:, 'USA'], :]

# %%
df
# Out:
#             pop  gdp
# yr country
# 16 USA        1    3
# 17 USA        3    5

# %%
df.index = df.index.droplevel(level = 1)

# %%
df
# Out:
#     pop  gdp
# yr
# 16    1    3
# 17    3    5

# %% [markdown]
# ## 연습문제
#
# 1.  연도(2017~2020), 국가별(kr, us, jp) 경제성장률과 물가상승률 데이터프레임을 생성하시오
#     - 인덱스 첫번째 레벨은 연도, 두번째 레벨은 국가명, 칼럼 라벨은 [gdp, inf]
#     - 경제성장률과 물가상승률은 넘파이 랜덤표본 이용
#
# 3.  2018년 이후 국가별 경제성장률과 물가상승률을 보이시오

# %%
df = pd.DataFrame({'country':['USA', 'KOR', 'USA', 'KOR'],
                   'pop':[1, 2, 3, 4],
                   'gdp':[3, 4, 5, 6]},
                  index = [16, 16, 17, 17])

# %%
list(range(2017, 2021)) * 3
# Out:
# [2017, 2018, 2019, 2020, 2017, 2018, 2019, 2020, 2017, 2018, 2019, 2020]

# %%
['kr'] * 4 + ['us'] * 4 + ['jp'] * 4
# Out:
# ['kr', 'kr', 'kr', 'kr', 'us', 'us', 'us', 'us', 'jp', 'jp', 'jp', 'jp']

# %%
ex1 = pd.DataFrame({'yr':list(range(2017, 2021)) * 3,
                    'country':['kr'] * 4 + ['us'] * 4 + ['jp'] * 4,
                    'gdp':np.random.randn(12) + 1,
                    'inf':np.random.randn(12) + 2})
ex1
# Out:
#       yr country       gdp       inf
# 0   2017      kr  0.731290  2.126947
# 1   2018      kr  0.826269  2.502862
# 2   2019      kr  1.566925  2.794292
# 3   2020      kr -0.766412  3.043916
# 4   2017      us  1.134977  2.513474
# 5   2018      us  0.126365 -0.610206
# 6   2019      us  1.046491  3.135422
# 7   2020      us  1.891498  1.505291
# 8   2017      jp  0.315119 -0.334759
# 9   2018      jp  2.591242  0.804197
# 10  2019      jp  1.055114  3.606504
# 11  2020      jp  0.759579  1.565419

# %%
ex1 = ex1.set_index(['yr', 'country'])
ex1 = ex1.sort_index()
ex1
# Out:
#                    gdp       inf
# yr   country
# 2017 jp       0.315119 -0.334759
#      kr       0.731290  2.126947
#      us       1.134977  2.513474
# 2018 jp       2.591242  0.804197
#      kr       0.826269  2.502862
#      us       0.126365 -0.610206
# 2019 jp       1.055114  3.606504
#      kr       1.566925  2.794292
#      us       1.046491  3.135422
# 2020 jp       0.759579  1.565419
#      kr      -0.766412  3.043916
#      us       1.891498  1.505291

# %%
import numpy as np

ex1 = pd.DataFrame({'yr':list(range(2017, 2021)) * 3,
                    'country':['kr'] * 4 + ['us'] * 4 + ['jp'] * 4,
                    'gdp':np.random.randn(12) + 1,
                    'inf':np.random.randn(12) + 2})
ex1 = ex1.set_index(['yr', 'country'])
ex1 = ex1.sort_index()
ex1.loc[2018:]
# Out:
#                    gdp       inf
# yr   country
# 2018 jp       1.457819  0.504065
#      kr       0.497973  2.280452
#      us      -0.459585  2.788227
# 2019 jp       1.328652  3.209142
#      kr       0.880251  2.604017
#      us       0.841283  4.282393
# 2020 jp       1.269639  1.365522
#      kr       2.078062  3.150988
#      us       1.026720  0.798215

# %% [markdown]
# # 연산

# %%
# 데이터프레임을 병렬로 표시하기 위한 함수 정의
from IPython.display import display_html
def display_by_side(*args):
    html_str=''
    for df in args:
        html_str+=df.to_html()
    display_html(html_str.replace('table','table style="display:inline"'),raw=True)

# %%
df = pd.DataFrame({'KOR':[1, 3], 'USA':[2, 4]})
df
# Out:
#    KOR  USA
# 0    1    2
# 1    3    4

# %%
df1 = df + 10
df1
# Out:
#    KOR  USA
# 0   11   12
# 1   13   14

# %%
df1.columns = ['USA', 'CHN']
df1
# Out:
#    USA  CHN
# 0   11   12
# 1   13   14

# %%
df
# Out:
#    KOR  USA
# 0    1    2
# 1    3    4

# %%
display_by_side(df1, df + df1)
# Out:
# <table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>USA</th>
#       <th>CHN</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>11</td>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>13</td>
#       <td>14</td>
#     </tr>
#   </tbody>
# </table style="display:inline"><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>CHN</th>
#       <th>KOR</th>
#       <th>USA</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>13</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>17</td>
#     </tr>
#   </tbody>
# </table style="display:inline">

# %%
df + df1
# Out:
#    CHN  KOR  USA
# 0  NaN  NaN   13
# 1  NaN  NaN   17

# %%
display_by_side(df, df.T)
# Out:
# <table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>KOR</th>
#       <th>USA</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>3</td>
#       <td>4</td>
#     </tr>
#   </tbody>
# </table style="display:inline"><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>KOR</th>
#       <td>1</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>USA</th>
#       <td>2</td>
#       <td>4</td>
#     </tr>
#   </tbody>
# </table style="display:inline">

# %%
df.dot(df.T)
# Out:
#     0   1
# 0   5  11
# 1  11  25

# %%
df.T.dot(df)
# Out:
#      KOR  USA
# KOR   10   14
# USA   14   20

# %%
display_by_side(df, df)
# Out:
# <table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>KOR</th>
#       <th>USA</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>3</td>
#       <td>4</td>
#     </tr>
#   </tbody>
# </table style="display:inline"><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>KOR</th>
#       <th>USA</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>3</td>
#       <td>4</td>
#     </tr>
#   </tbody>
# </table style="display:inline">

# %%
df.dot(df) # 행과 열의 이름이 다름
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7644\267589422.py in ?()
# ----> 1 df.dot(df) # 행과 열의 이름이 다름
#
# c:\Users\bok\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, other)
#    1733         """
#    1734         if isinstance(other, (Series, DataFrame)):
#    1735             common = self.columns.union(other.index)
#    1736             if len(common) > len(self.columns) or len(common) > len(other.index):
# -> 1737                 raise ValueError("matrices are not aligned")
#    1738
#    1739             left = self.reindex(columns=common, copy=False)
#    1740             right = other.reindex(index=common, copy=False)
#
# ValueError: matrices are not aligned

# %%
df1 = pd.DataFrame({'USA':[1, 3], 'CHN':[2, 4]})
df2 = pd.DataFrame({'JPN':[2, 4], 'KOR':[6, 8]})

# %%
display_by_side(df1, df2)
# Out:
# <table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>USA</th>
#       <th>CHN</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>3</td>
#       <td>4</td>
#     </tr>
#   </tbody>
# </table style="display:inline"><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>JPN</th>
#       <th>KOR</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>4</td>
#       <td>8</td>
#     </tr>
#   </tbody>
# </table style="display:inline">

# %%
pd.concat([df1, df2], axis = 1) # 열 방향 병합
# Out:
#    USA  CHN  JPN  KOR
# 0    1    2    2    6
# 1    3    4    4    8

# %%
pd.concat([df1, df2], axis = 0) # 행 방향 병합
# Out:
#    USA  CHN  JPN  KOR
# 0  1.0  2.0  NaN  NaN
# 1  3.0  4.0  NaN  NaN
# 0  NaN  NaN  2.0  6.0
# 1  NaN  NaN  4.0  8.0

# %%
df3 = pd.DataFrame({'USA': [2, 4], 'CHN': [3, 5]})
display_by_side(df1, df3)
# Out:
# <table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>USA</th>
#       <th>CHN</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>3</td>
#       <td>4</td>
#     </tr>
#   </tbody>
# </table style="display:inline"><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>USA</th>
#       <th>CHN</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>4</td>
#       <td>5</td>
#     </tr>
#   </tbody>
# </table style="display:inline">

# %%
pd.concat([df1, df3], axis = 0)
# Out:
#    USA  CHN
# 0    1    2
# 1    3    4
# 0    2    3
# 1    4    5

# %% [markdown]
# ## merge, concat

# %%
df2.columns = ['CHN', 'KOR']
df2
# Out:
#    CHN  KOR
# 0    2    6
# 1    4    8

# %%
df1
# Out:
#    USA  CHN
# 0    1    2
# 1    3    4

# %%
df1.merge(df2, on = 'CHN')
# Out:
#    USA  CHN  KOR
# 0    1    2    6
# 1    3    4    8

# %% [markdown]
# ## add, sub, mul, div

# %%
df
# Out:
#    KOR  USA
# 0    1    2
# 1    3    4

# %%
df['Total'] = df.sum(axis = 1) # 각 행의 원소를 모두 더해서 새로운 열 생성
df
# Out:
#    KOR  USA  Total
# 0    1    2      3
# 1    3    4      7

# %%
df.add(df)
# Out:
#    KOR  USA  Total
# 0    2    4      6
# 1    6    8     14

# %%
df.sub(df)
# Out:
#    KOR  USA  Total
# 0    0    0      0
# 1    0    0      0

# %%
df.mul(df)
# Out:
#    KOR  USA  Total
# 0    1    4      9
# 1    9   16     49

# %%
df.div(df.Total, axis = 0) # 행 기준으로 df.Total 각 원소 값으로 나눈다
# Out:
#         KOR       USA  Total
# 0  0.333333  0.666667    1.0
# 1  0.428571  0.571429    1.0

# %% [markdown]
# ## cut
#
# - 숫자 데이터를 범주형(category) 데이터로 변환
# - 데이터프레임 값을 미리 정의된 범위(ranges)에 따라 나눌 경우 pd.cut(df.var, ranges) 이용

# %%
from numpy.random import randint
df = pd.DataFrame({'a':range(4), 'b':randint(1,10,4)})
df
# Out:
#    a  b
# 0  0  3
# 1  1  9
# 2  2  6
# 3  3  9

# %%
pd.cut(df.b, [0, 7, 10])
# Out:
# 0     (0, 7]
# 1    (7, 10]
# 2     (0, 7]
# 3    (7, 10]
# Name: b, dtype: category
# Categories (2, interval[int64, right]): [(0, 7] < (7, 10]]

# %%
df.loc[:, 'c'] = pd.cut(df.b, [0, 7, 10], labels=False) # pd.cut( , , labels=False)는 범주 대신 숫자(구간 순서) 반환

# %%
df
# Out:
#    a  b  c
# 0  0  3  0
# 1  1  9  1
# 2  2  6  0
# 3  3  9  1

# %% [markdown]
# ## groupby: 특정 열을 기준으로 데이터프레임을 그룹으로 나누어 원하는 작업 수행

# %%
df = pd.DataFrame({'country':['USA', 'KOR', 'USA', 'KOR'],
                   'pop':[1, 2, 3, 4],
                   'gdp':[3, 4, 5, 6]},
                  index = [16, 16, 17, 17])

# %%
df
# Out:
#    country  pop  gdp
# 16     USA    1    3
# 16     KOR    2    4
# 17     USA    3    5
# 17     KOR    4    6

# %%
df.groupby('country').mean()
# Out:
#          pop  gdp
# country
# KOR      3.0  5.0
# USA      2.0  4.0

# %%
df = df[['pop', 'gdp']]
df
# Out:
#     pop  gdp
# 16    1    3
# 16    2    4
# 17    3    5
# 17    4    6

# %% [markdown]
# ## 특정 열이 아니라 값이 속한 범주에 따라 그룹지정

# %%
df.groupby(pd.cut(df['pop'], [0, 2, 4]))['gdp'].mean()
# Out:
# C:\Users\bok\AppData\Local\Temp\ipykernel_7644\976729260.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(pd.cut(df['pop'], [0, 2, 4]))['gdp'].mean()
# pop
# (0, 2]    3.5
# (2, 4]    5.5
# Name: gdp, dtype: float64

# %% [markdown]
# ## lambda 함수
# - apply, applymap과 함께 사용

# %%
square = lambda x: x * x

# %%
square(2)
# Out:
# 4

# %% [markdown]
# ## apply/applymap: apply는 열이나 행에 함수 적용, applymap은 각 요소에 함수 적용

# %%
df = pd.DataFrame({'country':['USA', 'KOR', 'USA', 'KOR'],
                   'pop':[1, 2, 3, 4],
                   'gdp':[3, 4, 5, 6]},
                  index = [16, 16, 17, 17])
df
# Out:
#    country  pop  gdp
# 16     USA    1    3
# 16     KOR    2    4
# 17     USA    3    5
# 17     KOR    4    6

# %%
df[['pop', 'gdp']].apply(lambda x: x.div(x.sum()))
# Out:
#     pop       gdp
# 16  0.1  0.166667
# 16  0.2  0.222222
# 17  0.3  0.277778
# 17  0.4  0.333333

# %%
df = df[['pop', 'gdp']].apply(lambda x: x.div(x.sum()))
df
# Out:
#     pop       gdp
# 16  0.1  0.166667
# 16  0.2  0.222222
# 17  0.3  0.277778
# 17  0.4  0.333333

# %%
df
# Out:
#    country  pop  gdp
# 16     USA    1    3
# 16     KOR    2    4
# 17     USA    3    5
# 17     KOR    4    6

# %%
df.applymap(lambda x: f'{x:.2f}')
# Out:
# C:\Users\bok\AppData\Local\Temp\ipykernel_7644\1105444861.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df.applymap(lambda x: f'{x:.2f}')
#      pop   gdp
# 16  0.10  0.17
# 16  0.20  0.22
# 17  0.30  0.28
# 17  0.40  0.33

# %% [markdown]
# ## stack/unstack
# - 데이터프레임의 데이터 구조를 재구성
# - 데이터프레임의 특정 행 또는 열을 다른 축(axis)로 이동할 때,
# - 만약 행 또는 열이 멀티인덱스인 경우 이동하려는 행 또는 열의 레벨을 지정

# %%
df = pd.DataFrame({'country':['USA', 'KOR', 'USA', 'KOR'],
                   'pop':[1, 2, 3, 4],
                   'gdp':[3, 4, 5, 6]},
                  index = [16, 16, 17, 17])

df = df.set_index('country', append=True)
df
# Out:
#             pop  gdp
#    country
# 16 USA        1    3
#    KOR        2    4
# 17 USA        3    5
#    KOR        4    6

# %%
df.unstack(level = 1) # 두번째 index를 열로
# Out:
#         pop     gdp
# country KOR USA KOR USA
# 16        2   1   4   3
# 17        4   3   6   5

# %%
df = df.unstack(level = 1)

# %%
df.stack(level = 1) # 열을 행으로
# Out:
# C:\Users\bok\AppData\Local\Temp\ipykernel_7644\3015370.py:1: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   df.stack(level = 1) # 열을 행으로
#             pop  gdp
#    country
# 16 KOR        2    4
#    USA        1    3
# 17 KOR        4    6
#    USA        3    5

# %% [markdown]
# # 시계열
# - 데이터프레임의 인덱스를 DatetimeIndex 자료형으로 지정하면 시계열 빈도 변경(resample), 증가율/차분(pct_change()/diff()
# - 특정 연도/월 선택 등 시계열 분석에 유용한 기능 제공

# %%
import numpy as np
df = pd.DataFrame(np.random.randint(1, 20, 24).reshape(12, 2), columns=['con', 'gdp'])

# %%
df
# Out:
#     con  gdp
# 0    13   15
# 1    19   18
# 2     1    7
# 3     7    7
# 4    19   18
# 5    15    6
# 6    10    4
# 7     3   19
# 8    13   19
# 9     2   10
# 10   13    7
# 11   17    2

# %% [markdown]
# ## pd.date_range(start=, end=, freq=), pd.to_datetime()

# %%
df.index = pd.date_range(start = '2017-3-31', end = '2019-12-31', freq='Q')
# Out:
# C:\Users\bok\AppData\Local\Temp\ipykernel_7644\2598558505.py:1: FutureWarning: 'Q' is deprecated and will be removed in a future version, please use 'QE' instead.
#   df.index = pd.date_range(start = '2017-3-31', end = '2019-12-31', freq='Q')

# %%
df
# Out:
#             con  gdp
# 2017-03-31   13   15
# 2017-06-30   19   18
# 2017-09-30    1    7
# 2017-12-31    7    7
# 2018-03-31   19   18
# 2018-06-30   15    6
# 2018-09-30   10    4
# 2018-12-31    3   19
# 2019-03-31   13   19
# 2019-06-30    2   10
# 2019-09-30   13    7
# 2019-12-31   17    2

# %%
type(df.index)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %% [markdown]
# ## resample

# %%
df.resample('A').sum()
# Out:
# C:\Users\bok\AppData\Local\Temp\ipykernel_7644\1752339685.py:1: FutureWarning: 'A' is deprecated and will be removed in a future version, please use 'YE' instead.
#   df.resample('A').sum()
#             con  gdp
# 2017-12-31   40   47
# 2018-12-31   47   47
# 2019-12-31   45   38

# %%
df.resample('A').last()
# Out:
# C:\Users\bok\AppData\Local\Temp\ipykernel_7644\3358058472.py:1: FutureWarning: 'A' is deprecated and will be removed in a future version, please use 'YE' instead.
#   df.resample('A').last()
#             con  gdp
# 2017-12-31    7    7
# 2018-12-31    3   19
# 2019-12-31   17    2

# %%
df.resample('A').mean()
# Out:
# C:\Users\bok\AppData\Local\Temp\ipykernel_7644\1338678549.py:1: FutureWarning: 'A' is deprecated and will be removed in a future version, please use 'YE' instead.
#   df.resample('A').mean()
#               con    gdp
# 2017-12-31  10.00  11.75
# 2018-12-31  11.75  11.75
# 2019-12-31  11.25   9.50

# %% [markdown]
# matplotlib

# %% [markdown]
# ## simple graph

# %%
df.plot()
# Out:
# <Axes: >

# %%
df.plot.bar()
# Out:
# <Axes: >

# %%
df
# Out:
#             con  gdp
# 2017-03-31   13   15
# 2017-06-30   19   18
# 2017-09-30    1    7
# 2017-12-31    7    7
# 2018-03-31   19   18
# 2018-06-30   15    6
# 2018-09-30   10    4
# 2018-12-31    3   19
# 2019-03-31   13   19
# 2019-06-30    2   10
# 2019-09-30   13    7
# 2019-12-31   17    2

# %%
df.resample('M').interpolate(method='cubic').plot() # 누락된 데이터를 추정하여 채움
# ‘nearest’, ‘zero’, ‘slinear’, ‘quadratic’, ‘cubic’, ‘spline’, ‘barycentric’, ‘polynomial’
# Out:
# C:\Users\bok\AppData\Local\Temp\ipykernel_7644\3979261251.py:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df.resample('M').interpolate(method='cubic').plot() # 누락된 데이터를 추정하여 채움
# <Axes: >

# %%
df.plot()
# ‘nearest’, ‘zero’, ‘slinear’, ‘quadratic’, ‘cubic’, ‘spline’, ‘barycentric’, ‘polynomial’
# Out:
# <Axes: >

# %%
df = pd.DataFrame({'value':[2, 4, 5, 6], 'date':['20201201', '2019-9-1', '1 jul 2018', '2017q1']})

# %%
df
# Out:
#    value        date
# 0      2    20201201
# 1      4    2019-9-1
# 2      5  1 jul 2018
# 3      6      2017q1

# %%
df.date = pd.to_datetime(df.date, format='mixed')

# %%
df
# Out:
#    value       date
# 0      2 2020-12-01
# 1      4 2019-09-01
# 2      5 2018-07-01
# 3      6 2017-01-01

# %%
df = df.set_index('date')

# %%
df
# Out:
#             value
# date
# 2020-12-01      2
# 2019-09-01      4
# 2018-07-01      5
# 2017-01-01      6

# %%
df = df.sort_index() # 오름차순으로 정렬
df
# Out:
#             value
# date
# 2017-01-01      6
# 2018-07-01      5
# 2019-09-01      4
# 2020-12-01      2

# %% [markdown]
# - 전기 대비 증가율, 차분 등 함수를 원래 의도대로 적용하기 위해서는 데이터프레임의 데이트타임인덱스가 빠짐없이 순서대로 정렬되어야 함
# - date_range()로 전체 샘플기간에 대한 데이터타임인덱스를 생성한 후 데이터프레임의 reindex(index)를 이용하여 적용

# %%
df.pct_change()
# Out:
#                value
# date
# 2017-01-01       NaN
# 2018-07-01 -0.166667
# 2019-09-01 -0.200000
# 2020-12-01 -0.500000

# %% [markdown]
# ## offsets: YearEnd(), YearBegin(), QuaterEnd(), QuaterBegin(), MonthEnd(), MonthBegin()
# - 날짜 표기를 일치시킬 때 사용

# %%
from pandas.tseries.offsets import YearEnd, YearBegin, QuarterEnd, QuarterBegin

# %%
df
# Out:
#             value
# date
# 2017-01-01      6
# 2018-07-01      5
# 2019-09-01      4
# 2020-12-01      2

# %%
df.index = df.index + YearEnd()
df
# Out:
#             value
# date
# 2017-12-31      6
# 2018-12-31      5
# 2019-12-31      4
# 2020-12-31      2

# %%
df = pd.DataFrame({'value':[2, 4, 5, 6], 'date':['20201201', '2019-9-1', '1 jul 2018', '2017q1']})
df.date = pd.to_datetime(df.date, format='mixed')
df = df.set_index('date')
df = df.sort_index()
df
# Out:
#             value
# date
# 2017-01-01      6
# 2018-07-01      5
# 2019-09-01      4
# 2020-12-01      2

# %%
df.index = df.index + QuarterEnd()
df
# Out:
#             value
# date
# 2017-03-31      6
# 2018-09-30      5
# 2019-09-30      4
# 2020-12-31      2

# %% [markdown]
# 데이트타임에서 연도, 분기, 월 추출

# %%
df = pd.DataFrame({'value':[2, 4, 5, 6], 'date':['20201201', '2019-9-1', '1 jul 2018', '2017q1']})
df.date = pd.to_datetime(df.date, format='mixed')

# %%
df
# Out:
#    value       date
# 0      2 2020-12-01
# 1      4 2019-09-01
# 2      5 2018-07-01
# 3      6 2017-01-01

# %%
df['month'] = df.date.dt.month

# %%
df
# Out:
#    value       date  month
# 0      2 2020-12-01     12
# 1      4 2019-09-01      9
# 2      5 2018-07-01      7
# 3      6 2017-01-01      1

# %%
df['day'] = df.date.dt.day

# %%
df
# Out:
#    value       date  month  day
# 0      2 2020-12-01     12    1
# 1      4 2019-09-01      9    1
# 2      5 2018-07-01      7    1
# 3      6 2017-01-01      1    1

# %% [markdown]
# # save/read

# %%
pwd # print working directory
# Out:
# '/content'

# %%
import os
os.getcwd()
# Out:
# 'c:\\Users\\bok\\Desktop\\bigdata\\bigdata'

# %%
import os
os.mkdir('pickles')

# %% [markdown]
# ## to_pickle()
#
# - python에서 매우 효율적임

# %%
ls # 현재 디렉토리에 있는 파일과 서브 디렉토리 표시
# Out:
#  C ����̺��� �������� �̸��� �����ϴ�.
#  ���� �Ϸ� ��ȣ: E8FD-BE1B
#
#  c:\Users\bok\Desktop\bigdata\bigdata ���͸�
#
#
#  c:\Users\bok\Desktop\bigdata\bigdata ���͸�
#
#
#  c:\Users\bok\Desktop\bigdata\bigdata ���͸�
#
#
#  c:\Users\bok\Desktop\bigdata\bigdata ���͸�
#
#
#  c:\Users\bok\Desktop\bigdata\bigdata ���͸�
#
#
#  c:\Users\bok\Desktop\bigdata\bigdata ���͸�
#
#
#  c:\Users\bok\Desktop\bigdata\bigdata ���͸�
#
#
#  c:\Users\bok\Desktop\bigdata\bigdata ���͸�
# ������ ã�� �� �����ϴ�.

# %%
os.listdir()
# Out:
# ['.git',
#  '.gitignore',
#  'data',
#  'ews',
#  'inflation',
#  'intro.ipynb',
#  'ml',
#  'numpy.ipynb',
#  'pandas1.ipynb',
#  'pandas2.ipynb',
#  'pickles',
#  'scripts',
#  '빅데이터 분석을 위한 파이썬.pdf']

# %%
df
# Out:
#    value       date  month  day
# 0      2 2020-12-01     12    1
# 1      4 2019-09-01      9    1
# 2      5 2018-07-01      7    1
# 3      6 2017-01-01      1    1

# %%
df.to_pickle('pickles/df.pkl')

# %%
ls pickles/
# Out:
# ����ġ�� Ʋ���ϴ� - "".

# %%
os.listdir('pickles')
# Out:
# ['df.pkl']

# %%
df1 = pd.read_pickle('pickles/df.pkl')

# %%
df1
# Out:
#    value       date  month  day
# 0      2 2020-12-01     12    1
# 1      4 2019-09-01      9    1
# 2      5 2018-07-01      7    1
# 3      6 2017-01-01      1    1

# %% [markdown]
# ## to_csv()

# %%
df.to_csv('df.csv')
df_csv = pd.read_csv('df.csv', index_col=0)

# %%
df_csv
# Out:
#    value        date  month  day
# 0      2  2020-12-01     12    1
# 1      4  2019-09-01      9    1
# 2      5  2018-07-01      7    1
# 3      6  2017-01-01      1    1

# %% [markdown]
# ## to_excel()

# %%
df.to_excel('df.xlsx')

# %% [markdown]
# ## save multiple dataframes

# %%
df
# Out:
#    value       date  month  day
# 0      2 2020-12-01     12    1
# 1      4 2019-09-01      9    1
# 2      5 2018-07-01      7    1
# 3      6 2017-01-01      1    1

# %%
df1
# Out:
#    value       date  month  day
# 0      2 2020-12-01     12    1
# 1      4 2019-09-01      9    1
# 2      5 2018-07-01      7    1
# 3      6 2017-01-01      1    1

# %%
df2
# Out:
#    CHN  KOR
# 0    2    6
# 1    4    8

# %%
dfs = {'df': df, 'df1': df1, 'df2': df2}

# %%
dfs['df']
# Out:
#    value       date  month  day
# 0      2 2020-12-01     12    1
# 1      4 2019-09-01      9    1
# 2      5 2018-07-01      7    1
# 3      6 2017-01-01      1    1

# %%
import pickle

# %%
with open('dfs.pkl', 'wb') as handle:
    pickle.dump(dfs, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
with open('dfs.pkl', 'rb') as handle:
    dfs_pkl = pickle.load(handle)

# %%
dfs_pkl['df']
# Out:
#    value       date  month  day
# 0      2 2020-12-01     12    1
# 1      4 2019-09-01      9    1
# 2      5 2018-07-01      7    1
# 3      6 2017-01-01      1    1

# %% [markdown]
# # matplotlib: 시각화 라이브러리

# %%
import pandas as pd

df = pd.DataFrame([0, 1, 2, 3, 4, 4], columns = ['y'])
df.plot()
# Out:
# <Axes: >

# %%
# %matplotlib notebook

# %%
df
# Out:
#    y
# 0  0
# 1  1
# 2  2
# 3  3
# 4  4
# 5  4

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(1, 2, figsize=(12, 4))

df.plot(ax=ax[0])
df.loc[2:].plot(ax=ax[1])
ax[1].legend(loc='lower right', fontsize=18)
ax[0].set_title('ax1')
fig.suptitle('graph', fontsize=18)
# Out:
# Text(0.5, 0.98, 'graph')

# %% [markdown]
# ## x, y-axis

# %%
from matplotlib.ticker import FuncFormatter as FF

fig, ax = plt.subplots(1, 2, figsize=(12, 4))

df.plot(ax=ax[0])
df.loc[2:].plot(ax=ax[1])
ax[1].legend(loc=4, fontsize=18)
ax[0].set_title('ax1')
fig.suptitle('graph', fontsize=18);

dp1 = lambda x, p: '{:,.1f}'.format(x)
dp0 = lambda x, p: '{:,.0f}'.format(x)
ax[1].yaxis.set_major_formatter(FF(dp1))
ax[1].xaxis.set_major_formatter(FF(dp0))

# %%
df
# Out:
#    y
# 0  0
# 1  1
# 2  2
# 3  3
# 4  4
# 5  4

# %%
df['x'] = df['y'] * 2

fig, ax = plt.subplots(1, 3, figsize=(12, 4))

df.plot.bar(ax=ax[0])
df.plot.bar(stacked=True, ax=ax[1])
df.plot.scatter(x='x', y='y', ax=ax[2])
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %% [markdown]
# ## bar chart

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(np.random.randint(1, 20, 24).reshape(12, 2), columns=['con', 'gdp'],
                  index = pd.date_range('2017-3-31', '2019-12-31', freq='Q'))
df
# Out:
# C:\Users\bok\AppData\Local\Temp\ipykernel_7644\4166405093.py:4: FutureWarning: 'Q' is deprecated and will be removed in a future version, please use 'QE' instead.
#   index = pd.date_range('2017-3-31', '2019-12-31', freq='Q'))
#             con  gdp
# 2017-03-31    6   14
# 2017-06-30   18    6
# 2017-09-30   17    3
# 2017-12-31    7    9
# 2018-03-31    8   19
# 2018-06-30    5   17
# 2018-09-30   12    9
# 2018-12-31    7   16
# 2019-03-31    3    3
# 2019-06-30   19   14
# 2019-09-30   19    2
# 2019-12-31    8    5

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(1, 1)

df.plot.bar(ax=ax)
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(1, 1)

df.plot.bar(ax=ax)

ticklabels = [pd.to_datetime(t.get_text()).strftime('%b\n%y') for t in ax.get_xticklabels()]
#ticklabels = [pd.to_datetime(t.get_text()).strftime('%y\n%m') for t in ax.get_xticklabels()]
ax.set_xticklabels(ticklabels, rotation=45);

# %%
def xaxis_date_format(ax, fmt = '%y'):
    '''fmt: '%b\n%y', '%y-%m-%d', etc '''
    ticklabels = [pd.to_datetime(t.get_text()).strftime(fmt) for t in ax.get_xticklabels()]
    ax.set_xticklabels(ticklabels, rotation=0)

# %%
fig, ax = plt.subplots(1, 1)

df.plot.bar(ax=ax)

#ticklabels = [pd.to_datetime(t.get_text()).strftime('%b\n%y') for t in ax.get_xticklabels()]
xaxis_date_format(ax, fmt = '%b\n%y')

# %% [markdown]
# ## 한글

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(np.random.randn(100).cumsum(), columns=['환율'])
df.plot()
# Out:
# <Axes: >
# c:\Users\bok\anaconda3\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 54872 (\N{HANGUL SYLLABLE HWAN}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# c:\Users\bok\anaconda3\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 50984 (\N{HANGUL SYLLABLE YUL}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# c:\Users\bok\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 54872 (\N{HANGUL SYLLABLE HWAN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\bok\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 50984 (\N{HANGUL SYLLABLE YUL}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# 현재 matplotlib가 사용할 수 있는 한글폰트 확인

# %%
import matplotlib.font_manager as fm
[f for f in fm.fontManager.ttflist if 'Nanum' in f.name]
# Out:
# [FontEntry(fname='C:\\Windows\\Fonts\\\x7f\x7f\x7f\x7f.TTF', name='NanumGothic', style='normal', variant='normal', weight=400, stretch='normal', size='scalable'),
#  FontEntry(fname='C:\\Windows\\Fonts\\\x7f\x7f\x7f\x7fBOLD.TTF', name='NanumGothic', style='normal', variant='normal', weight=600, stretch='normal', size='scalable'),
#  FontEntry(fname='C:\\Windows\\Fonts\\\x7f\x7f\x7f\x7fEXTRABOLD.TTF', name='NanumGothic', style='normal', variant='normal', weight=700, stretch='normal', size='scalable'),
#  FontEntry(fname='C:\\Users\\bok\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NanumMyeongjo.ttf', name='NanumMyeongjo', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')]

# %% [markdown]
# 나눔글꼴 설치(리눅스)

# %%
# !apt-get -y install fonts-nanum
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 45 not upgraded.
# Need to get 10.3 MB of archives.
# After this operation, 34.1 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-nanum all 20200506-1 [10.3 MB]
# Fetched 10.3 MB in 0s (36.9 MB/s)
# Selecting previously unselected package fonts-nanum.
# (Reading database ... 121925 files and directories currently installed.)
# Preparing to unpack .../fonts-nanum_20200506-1_all.deb ...
# Unpacking fonts-nanum (20200506-1) ...
# Setting up fonts-nanum (20200506-1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...

# %% [markdown]
# matplotlib가 사용할 수 있는 폰트 리스트를 재구성하고, 코랩 재시작

# %%
# !pip show matplotlib
# Out:
# Name: matplotlib
# Version: 3.9.0
# Summary: Python plotting package
# Home-page:
# Author: John D. Hunter, Michael Droettboom
# Author-email: Unknown <matplotlib-users@python.org>
# License: License agreement for matplotlib versions 1.3.0 and later
#         =========================================================
#
#         1. This LICENSE AGREEMENT is between the Matplotlib Development Team
#         ("MDT"), and the Individual or Organization ("Licensee") accessing and
#         otherwise using matplotlib software in source or binary form and its
#         associated documentation.
#
#         2. Subject to the terms and conditions of this License Agreement, MDT
#         hereby grants Licensee a nonexclusive, royalty-free, world-wide license
#         to reproduce, analyze, test, perform and/or display publicly, prepare
#         derivative works, distribute, and otherwise use matplotlib
#         alone or in any derivative version, provided, however, that MDT's
#         License Agreement and MDT's notice of copyright, i.e., "Copyright (c)
#         2012- Matplotlib Development Team; All Rights Reserved" are retained in
#         matplotlib  alone or in any derivative version prepared by
#         Licensee.
#
#         3. In the event Licensee prepares a derivative work that is based on or
#         incorporates matplotlib or any part thereof, and wants to
#         make the derivative work available to others as provided herein, then
#         Licensee hereby agrees to include in any such work a brief summary of
#         the changes made to matplotlib .
#
#         4. MDT is making matplotlib available to Licensee on an "AS
#         IS" basis.  MDT MAKES NO REPRESENTATIONS OR WARRANTIES, EXPRESS OR
#         IMPLIED.  BY WAY OF EXAMPLE, BUT NOT LIMITATION, MDT MAKES NO AND
#         DISCLAIMS ANY REPRESENTATION OR WARRANTY OF MERCHANTABILITY OR FITNESS
#         FOR ANY PARTICULAR PURPOSE OR THAT THE USE OF MATPLOTLIB
#         WILL NOT INFRINGE ANY THIRD PARTY RIGHTS.
#
#         5. MDT SHALL NOT BE LIABLE TO LICENSEE OR ANY OTHER USERS OF MATPLOTLIB
#          FOR ANY INCIDENTAL, SPECIAL, OR CONSEQUENTIAL DAMAGES OR
#         LOSS AS A RESULT OF MODIFYING, DISTRIBUTING, OR OTHERWISE USING
#         MATPLOTLIB , OR ANY DERIVATIVE THEREOF, EVEN IF ADVISED OF
#         THE POSSIBILITY THEREOF.
#
#         6. This License Agreement will automatically terminate upon a material
#         breach of its terms and conditions.
#
#         7. Nothing in this License Agreement shall be deemed to create any
#         relationship of agency, partnership, or joint venture between MDT and
#         Licensee.  This License Agreement does not grant permission to use MDT
#         trademarks or trade name in a trademark sense to endorse or promote
#         products or services of Licensee, or any third party.
#
#         8. By copying, installing or otherwise using matplotlib ,
#         Licensee agrees to be bound by the terms and conditions of this License
#         Agreement.
#
#         License agreement for matplotlib versions prior to 1.3.0
#         ========================================================
#
#         1. This LICENSE AGREEMENT is between John D. Hunter ("JDH"), and the
#         Individual or Organization ("Licensee") accessing and otherwise using
#         matplotlib software in source or binary form and its associated
#         documentation.
#
#         2. Subject to the terms and conditions of this License Agreement, JDH
#         hereby grants Licensee a nonexclusive, royalty-free, world-wide license
#         to reproduce, analyze, test, perform and/or display publicly, prepare
#         derivative works, distribute, and otherwise use matplotlib
#         alone or in any derivative version, provided, however, that JDH's
#         License Agreement and JDH's notice of copyright, i.e., "Copyright (c)
#         2002-2011 John D. Hunter; All Rights Reserved" are retained in
#         matplotlib  alone or in any derivative version prepared by
#         Licensee.
#
#         3. In the event Licensee prepares a derivative work that is based on or
#         incorporates matplotlib  or any part thereof, and wants to
#         make the derivative work available to others as provided herein, then
#         Licensee hereby agrees to include in any such work a brief summary of
#         the changes made to matplotlib.
#
#         4. JDH is making matplotlib  available to Licensee on an "AS
#         IS" basis.  JDH MAKES NO REPRESENTATIONS OR WARRANTIES, EXPRESS OR
#         IMPLIED.  BY WAY OF EXAMPLE, BUT NOT LIMITATION, JDH MAKES NO AND
#         DISCLAIMS ANY REPRESENTATION OR WARRANTY OF MERCHANTABILITY OR FITNESS
#         FOR ANY PARTICULAR PURPOSE OR THAT THE USE OF MATPLOTLIB
#         WILL NOT INFRINGE ANY THIRD PARTY RIGHTS.
#
#         5. JDH SHALL NOT BE LIABLE TO LICENSEE OR ANY OTHER USERS OF MATPLOTLIB
#          FOR ANY INCIDENTAL, SPECIAL, OR CONSEQUENTIAL DAMAGES OR
#         LOSS AS A RESULT OF MODIFYING, DISTRIBUTING, OR OTHERWISE USING
#         MATPLOTLIB , OR ANY DERIVATIVE THEREOF, EVEN IF ADVISED OF
#         THE POSSIBILITY THEREOF.
#
#         6. This License Agreement will automatically terminate upon a material
#         breach of its terms and conditions.
#
#         7. Nothing in this License Agreement shall be deemed to create any
#         relationship of agency, partnership, or joint venture between JDH and
#         Licensee.  This License Agreement does not grant permission to use JDH
#         trademarks or trade name in a trademark sense to endorse or promote
#         products or services of Licensee, or any third party.
#
#         8. By copying, installing or otherwise using matplotlib,
#         Licensee agrees to be bound by the terms and conditions of this License
#         Agreement.
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: contourpy, cycler, fonttools, kiwisolver, numpy, packaging, pillow, pyparsing, python-dateutil
# Required-by: arviz, bigframes, datascience, fastai, geemap, imgaug, matplotlib-venn, missingno, mizani, mlxtend, music21, plotnine, prophet, pycocotools, seaborn, wordcloud, yellowbrick

# %%
# !pip install --upgrade matplotlib
# Out:
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Collecting matplotlib
#   Downloading matplotlib-3.9.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 40.8 MB/s eta 0:00:00
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Installing collected packages: matplotlib
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.7.1
#     Uninstalling matplotlib-3.7.1:
#       Successfully uninstalled matplotlib-3.7.1
# Successfully installed matplotlib-3.9.0

# %%
import os
import matplotlib.font_manager as fm

fm._rebuild()
#fm._load_fontmanager()
os.kill(os.getpid(), 9)

# %% [markdown]
# 현재 matplotlib가 사용할 수 있는 한글폰트 확인

# %%
import matplotlib.font_manager as fm
[f for f in fm.fontManager.ttflist if 'Nanum' in f.name]
# Out:
# [FontEntry(fname='/usr/share/fonts/truetype/nanum/NanumGothic.ttf', name='NanumGothic', style='normal', variant='normal', weight=400, stretch='normal', size='scalable'),
#  FontEntry(fname='/usr/share/fonts/truetype/nanum/NanumBarunGothicBold.ttf', name='NanumBarunGothic', style='normal', variant='normal', weight=600, stretch='normal', size='scalable'),
#  FontEntry(fname='/usr/share/fonts/truetype/nanum/NanumSquareRoundB.ttf', name='NanumSquareRound', style='normal', variant='normal', weight=700, stretch='normal', size='scalable'),
#  FontEntry(fname='/usr/share/fonts/truetype/nanum/NanumSquareR.ttf', name='NanumSquare', style='normal', variant='normal', weight=400, stretch='normal', size='scalable'),
#  FontEntry(fname='/usr/share/fonts/truetype/nanum/NanumSquareRoundR.ttf', name='NanumSquareRound', style='normal', variant='normal', weight=400, stretch='normal', size='scalable'),
#  FontEntry(fname='/usr/share/fonts/truetype/nanum/NanumGothicCodingBold.ttf', name='NanumGothicCoding', style='normal', variant='normal', weight=700, stretch='normal', size='scalable'),
#  FontEntry(fname='/usr/share/fonts/truetype/nanum/NanumMyeongjo.ttf', name='NanumMyeongjo', style='normal', variant='normal', weight=400, stretch='normal', size='scalable'),
#  FontEntry(fname='/usr/share/fonts/truetype/nanum/NanumGothicCoding.ttf', name='NanumGothicCoding', style='normal', variant='normal', weight=400, stretch='normal', size='scalable'),
#  FontEntry(fname='/usr/share/fonts/truetype/nanum/NanumGothicBold.ttf', name='NanumGothic', style='normal', variant='normal', weight=600, stretch='normal', size='scalable'),
#  FontEntry(fname='/usr/share/fonts/truetype/nanum/NanumSquareB.ttf', name='NanumSquare', style='normal', variant='normal', weight=700, stretch='normal', size='scalable'),
#  FontEntry(fname='/usr/share/fonts/truetype/nanum/NanumMyeongjoBold.ttf', name='NanumMyeongjo', style='normal', variant='normal', weight=600, stretch='normal', size='scalable'),
#  FontEntry(fname='/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf', name='NanumBarunGothic', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')]

# %% [markdown]
# matplotlib에서 사용하려는 한글 폰트 지정하고, 그래프의 마이너스 라벨이 제대로 표시되도록 설정

# %%
import matplotlib.pyplot as plt

plt.rc('font', family='NanumGothic')
plt.rcParams['axes.unicode_minus'] = False

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(np.random.randn(100).cumsum(), columns=['환율'])
df.plot()
# Out:
# <Axes: >

# %% [markdown]
# # 연습문제
#
# 1. 성인 500명에 대한 키(cm)와 몸무게(kg) 데이터를 아래 관계에 따라 데이터프레임으로 생성하시오
#
# $height \sim norm(170, 15)$
#
# $weight = (height - 100){1.2} + u$, $u \sim norm(0, 5)$
#
# 2. 키와 몸무게 각각에 대한 히스토그램(5 kg/cm 구간)을 subplots을 이용하여 그리시오
#
# 3. 키 180cm 이상 및 이하로 그룹을 나누어 키와 몸무게의 산포도를 그리시오

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

N = 500
h = np.random.normal(170, 15, N)
w = (h - 100) * 1.2 + np.random.normal(0, 5, N)

hw = pd.DataFrame({'h':h, 'w':w})
print(hw.max())
print(hw.min())

fig, ax = plt.subplots(1, 2, figsize=(16, 4))
hw.groupby(pd.cut(hw.h, list(range(130, 205, 5))))['h'].count().plot.bar(ax=ax[0])
hw.groupby(pd.cut(hw.w, list(range(40, 140, 5))))['w'].count().plot.bar(ax=ax[1])

fig, ax = plt.subplots(1, 2, figsize=(16, 4))
hw.loc[hw.h.ge(180)].plot.scatter(x='h', y='w', ax=ax[0])
hw.loc[hw.h.lt(180)].plot.scatter(x='h', y='w', ax=ax[1])
# Out:
# h    214.442276
# w    144.384974
# dtype: float64
# h    118.402035
# w     19.242464
# dtype: float64
# <Axes: xlabel='h', ylabel='w'>
